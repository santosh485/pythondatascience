# %%
import pandas as pd
import numpy as np

# %%
person = {
    "first": ["Charlie", 'Jane', 'Uncle'], 
    "last": ["Chaplin", 'Does', 'Ben'], 
    "email": ["chaplin@gmail.com", 'JaneDoes@email.com', 'ben@email.com']
}
persons = pd.DataFrame(person,index=['one','two','three'])
persons
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5db9a9688610> in <module>
#       4     "email": ["chaplin@gmail.com", 'JaneDoes@email.com', 'ben@email.com']
#       5 }
# ----> 6 persons = pd.DataFrame(person,index=['one','two','three'])
#       7 persons
#
# NameError: name 'pd' is not defined

# %%
type(persons['email'])
# Out:
# pandas.core.series.Series

# %%
newrow1=pd.Series({'email':'kpbaa@gmail.com','first': 'K.P.', 'last': 'Oli'})
newrow1
# Out:
# email    kpbaa@gmail.com
# first               K.P.
# last                 Oli
# dtype: object

# %%
person1=persons.append(newrow1,ignore_index=True)  #ignore_index=True (reset labelled index)
person1
# Out:
#      first     last               email
# 0  Charlie  Chaplin   chaplin@gmail.com
# 1     Jane     Does  JaneDoes@email.com
# 2    Uncle      Ben       ben@email.com
# 3     K.P.      Oli     kpbaa@gmail.com

# %%
newrow2=pd.Series({'email':'kpbaa@gmail.com','first': 'K.P.', 'last': 'Oli'},name='four')
person2=persons.append(newrow2)
person2
# Out:
#          first     last               email
# one    Charlie  Chaplin   chaplin@gmail.com
# two       Jane     Does  JaneDoes@email.com
# three    Uncle      Ben       ben@email.com
# four      K.P.      Oli     kpbaa@gmail.com

# %%
persons
# Out:
#          first     last               email
# one    Charlie  Chaplin   chaplin@gmail.com
# two       Jane     Does  JaneDoes@email.com
# three    Uncle      Ben       ben@email.com

# %%
newrow3=pd.Series({'email':'newmail@gmail.com','first': 'XYZ', 'last': 'BLC'},name='four')
person2=person2.append(newrow3)
person2
# Out:
#          first     last               email
# one    Charlie  Chaplin   chaplin@gmail.com
# two       Jane     Does  JaneDoes@email.com
# three    Uncle      Ben       ben@email.com
# four      K.P.      Oli     kpbaa@gmail.com
# four       XYZ      BLC   newmail@gmail.com

# %%
person2.index
# Out:
# Index(['one', 'two', 'three', 'four', 'four'], dtype='object')

# %%
person2.loc['four']
# Out:
#      first last              email
# four  K.P.  Oli    kpbaa@gmail.com
# four   XYZ  BLC  newmail@gmail.com

# %%
person2.iloc[3]
# Out:
# first               K.P.
# last                 Oli
# email    kpbaa@gmail.com
# Name: four, dtype: object

# %%
personf = person2
personf
# Out:
#          first     last               email
# one    Charlie  Chaplin   chaplin@gmail.com
# two       Jane     Does  JaneDoes@email.com
# three    Uncle      Ben       ben@email.com
# four      K.P.      Oli     kpbaa@gmail.com
# four       XYZ      BLC   newmail@gmail.com

# %%
newDF = pd.DataFrame({"first": ["Raj", 'Snow', 'Marlon'], 
    "last": ["Bhandari", 'White', 'Samuel'], 
    "email": ['','',''],
    "age": ['','','']})
newDF
# Out:
#     first      last email age
# 0     Raj  Bhandari
# 1    Snow     White
# 2  Marlon    Samuel

# %%
personf=personf.append(newDF)
personf
# Out:
#          first      last               email  age
# one    Charlie   Chaplin   chaplin@gmail.com  NaN
# two       Jane      Does  JaneDoes@email.com  NaN
# three    Uncle       Ben       ben@email.com  NaN
# four      K.P.       Oli     kpbaa@gmail.com  NaN
# four       XYZ       BLC   newmail@gmail.com  NaN
# 0          Raj  Bhandari
# 1         Snow     White
# 2       Marlon    Samuel

# %%
personf.loc[1]
# Out:
# first     Snow
# last     White
# email
# age
# Name: 1, dtype: object

# %%
personf.iloc[1]
# Out:
# first                  Jane
# last                   Does
# email    JaneDoes@email.com
# age                     NaN
# Name: two, dtype: object

# %%
person2.index
# Out:
# Index(['one', 'two', 'three', 'four', 'four'], dtype='object')

# %%
person2.index.duplicated()
# Out:
# array([False, False, False, False,  True])

# %%
personf.index
# Out:
# Index(['one', 'two', 'three', 'four', 'four', 0, 1, 2], dtype='object')

# %%
persondf = personf.rename(index={0:'zero',1:'newone',2:'newtwo'})

# %%
persondf
# Out:
#           first      last               email  age
# one     Charlie   Chaplin   chaplin@gmail.com  NaN
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com  NaN
# four        XYZ       BLC   newmail@gmail.com  NaN
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel

# %%
df=persondf
df
# Out:
#           first      last               email  age
# one     Charlie   Chaplin   chaplin@gmail.com  NaN
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com  NaN
# four        XYZ       BLC   newmail@gmail.com  NaN
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel

# %%
df.reset_index(inplace=True)
df
# Out:
#     index    first      last               email  age
# 0     one  Charlie   Chaplin   chaplin@gmail.com  NaN
# 1     two     Jane      Does  JaneDoes@email.com  NaN
# 2   three    Uncle       Ben       ben@email.com  NaN
# 3    four     K.P.       Oli     kpbaa@gmail.com  NaN
# 4    four      XYZ       BLC   newmail@gmail.com  NaN
# 5    zero      Raj  Bhandari
# 6  newone     Snow     White
# 7  newtwo   Marlon    Samuel

# %%
df.columns
# Out:
# Index(['index', 'first', 'last', 'email', 'age'], dtype='object')

# %%
df.iloc[3]
# Out:
# index               four
# first               K.P.
# last                 Oli
# email    kpbaa@gmail.com
# age                  NaN
# Name: 3, dtype: object

# %%
df.loc[4,'index']
# Out:
# 'four'

# %%
df.loc[4,'index']='five'

# %%
df
# Out:
#     index    first      last               email  age
# 0     one  Charlie   Chaplin   chaplin@gmail.com  NaN
# 1     two     Jane      Does  JaneDoes@email.com  NaN
# 2   three    Uncle       Ben       ben@email.com  NaN
# 3    four     K.P.       Oli     kpbaa@gmail.com  NaN
# 4    five      XYZ       BLC   newmail@gmail.com  NaN
# 5    zero      Raj  Bhandari
# 6  newone     Snow     White
# 7  newtwo   Marlon    Samuel

# %%
df.set_index(df['index'],inplace=True)

# %%
df
# Out:
#          index    first      last               email  age
# index
# one        one  Charlie   Chaplin   chaplin@gmail.com  NaN
# two        two     Jane      Does  JaneDoes@email.com  NaN
# three    three    Uncle       Ben       ben@email.com  NaN
# four      four     K.P.       Oli     kpbaa@gmail.com  NaN
# five      five      XYZ       BLC   newmail@gmail.com  NaN
# zero      zero      Raj  Bhandari
# newone  newone     Snow     White
# newtwo  newtwo   Marlon    Samuel

# %%
df.dropna()
# Out:
#          index   first      last email age
# index
# zero      zero     Raj  Bhandari
# newone  newone    Snow     White
# newtwo  newtwo  Marlon    Samuel

# %%
df
# Out:
#          index    first      last               email  age
# index
# one        one  Charlie   Chaplin   chaplin@gmail.com  NaN
# two        two     Jane      Does  JaneDoes@email.com  NaN
# three    three    Uncle       Ben       ben@email.com  NaN
# four      four     K.P.       Oli     kpbaa@gmail.com  NaN
# five      five      XYZ       BLC   newmail@gmail.com  NaN
# zero      zero      Raj  Bhandari
# newone  newone     Snow     White
# newtwo  newtwo   Marlon    Samuel

# %%
df.dropna(axis=0,subset=['age'])
# Out:
#          index   first      last email age
# index
# zero      zero     Raj  Bhandari
# newone  newone    Snow     White
# newtwo  newtwo  Marlon    Samuel

# %%
df.drop('index',1,inplace=True)

# %%
df
# Out:
#           first      last               email  age
# index
# one     Charlie   Chaplin   chaplin@gmail.com  NaN
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com  NaN
# five        XYZ       BLC   newmail@gmail.com  NaN
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel

# %%
df.index.drop_duplicates()
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'zero', 'newone', 'newtwo'], dtype='object', name='index')

# %%
df=df.append(pd.Series({'email':'kpbaa@gmail.com','first': 'K.P.', 'last': 'Oli'},name='test1'))
df=df.append(pd.Series({'email':'kpbaa@gmail.com','first': 'K.P.', 'last': 'Oli'},name='test2'))
df
# Out:
#           first      last               email  age
# index
# one     Charlie   Chaplin   chaplin@gmail.com  NaN
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com  NaN
# five        XYZ       BLC   newmail@gmail.com  NaN
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel
# test1      K.P.       Oli     kpbaa@gmail.com  NaN
# test2      K.P.       Oli     kpbaa@gmail.com  NaN

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#           first      last               email  age
# index
# one     Charlie   Chaplin   chaplin@gmail.com  NaN
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com  NaN
# five        XYZ       BLC   newmail@gmail.com  NaN
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel

# %%
df.drop_duplicates(subset=['last'],inplace=True)

# %%
df
# Out:
#           first      last               email  age
# index
# one     Charlie   Chaplin   chaplin@gmail.com  NaN
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com  NaN
# five        XYZ       BLC   newmail@gmail.com  NaN
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel

# %%
df=df.append(pd.Series({'email':'peter2@gmail.com','first': 'Peter2', 'last': 'Bro2'},name='tests2'))
df=df.append(pd.Series({'email':'peter@gmail.com','first': 'Peter', 'last': 'Bro'},name='tests'))
df
# Out:
#           first      last               email  age
# index
# one     Charlie   Chaplin   chaplin@gmail.com  NaN
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com  NaN
# five        XYZ       BLC   newmail@gmail.com  NaN
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel
# tests2   Peter2      Bro2    peter2@gmail.com  NaN
# tests     Peter       Bro     peter@gmail.com  NaN

# %%
condition=df['email'] =='peter@gmail.com'
df[condition].index
# Out:
# Index(['tests'], dtype='object', name='index')

# %%
condition=df['email'] =='peter@gmail.com'
df.drop(index=df[condition].index,inplace=True)
df
# Out:
#           first      last               email  age
# index
# one     Charlie   Chaplin   chaplin@gmail.com  NaN
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com  NaN
# five        XYZ       BLC   newmail@gmail.com  NaN
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel
# tests2   Peter2      Bro2    peter2@gmail.com  NaN

# %%
condition = df['email'].filter(regex='\w\d+')

# %%
condition
# Out:
# index
# tests2    peter2@gmail.com
# Name: email, dtype: object

# %%
df.drop(index=condition.index,inplace=True)
df
# Out:
#           first      last               email  age
# index
# one     Charlie   Chaplin   chaplin@gmail.com  NaN
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com  NaN
# five        XYZ       BLC   newmail@gmail.com  NaN
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel

# %%
df.loc['one','age']=89
df.loc['four','age']=78

# %%
df
# Out:
#           first      last               email  age
# index
# one     Charlie   Chaplin   chaplin@gmail.com   89
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com   78
# five        XYZ       BLC   newmail@gmail.com  NaN
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# index
# one        CHAPLIN@GMAIL.COM
# two       JANEDOES@EMAIL.COM
# three          BEN@EMAIL.COM
# four         KPBAA@GMAIL.COM
# five       NEWMAIL@GMAIL.COM
# zero
# newone
# newtwo
# Name: email, dtype: object

# %%
df1=df

# %%
df1
# Out:
#           first      last               email  age
# index
# one     Charlie   Chaplin   chaplin@gmail.com   89
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com   78
# five        XYZ       BLC   newmail@gmail.com  NaN
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel

# %%
df1.sort_values(by='email',ascending=True)
# Out:
#           first      last               email  age
# index
# zero        Raj  Bhandari
# newone     Snow     White
# newtwo   Marlon    Samuel
# two        Jane      Does  JaneDoes@email.com  NaN
# three     Uncle       Ben       ben@email.com  NaN
# one     Charlie   Chaplin   chaplin@gmail.com   89
# four       K.P.       Oli     kpbaa@gmail.com   78
# five        XYZ       BLC   newmail@gmail.com  NaN

# %%
df1.sort_values(by=['last','first'],ascending=False)
# Out:
#           first      last               email  age
# index
# newone     Snow     White
# newtwo   Marlon    Samuel
# four       K.P.       Oli     kpbaa@gmail.com   78
# two        Jane      Does  JaneDoes@email.com  NaN
# one     Charlie   Chaplin   chaplin@gmail.com   89
# zero        Raj  Bhandari
# three     Uncle       Ben       ben@email.com  NaN
# five        XYZ       BLC   newmail@gmail.com  NaN

# %%
df1.sort_index()
# Out:
#           first      last               email  age
# index
# five        XYZ       BLC   newmail@gmail.com  NaN
# four       K.P.       Oli     kpbaa@gmail.com   78
# newone     Snow     White
# newtwo   Marlon    Samuel
# one     Charlie   Chaplin   chaplin@gmail.com   89
# three     Uncle       Ben       ben@email.com  NaN
# two        Jane      Does  JaneDoes@email.com  NaN
# zero        Raj  Bhandari

# %%
df1.sort_index(axis=1, inplace=True,ascending=False)
df1
# Out:
#             last    first               email  age
# index
# one      Chaplin  Charlie   chaplin@gmail.com   89
# two         Does     Jane  JaneDoes@email.com  NaN
# three        Ben    Uncle       ben@email.com  NaN
# four         Oli     K.P.     kpbaa@gmail.com   78
# five         BLC      XYZ   newmail@gmail.com  NaN
# zero    Bhandari      Raj
# newone     White     Snow
# newtwo    Samuel   Marlon

# %%
df1[sorted(df1)]
# Out:
#         age               email    first      last
# index
# one      89   chaplin@gmail.com  Charlie   Chaplin
# two     NaN  JaneDoes@email.com     Jane      Does
# three   NaN       ben@email.com    Uncle       Ben
# four     78     kpbaa@gmail.com     K.P.       Oli
# five    NaN   newmail@gmail.com      XYZ       BLC
# zero                                 Raj  Bhandari
# newone                              Snow     White
# newtwo                            Marlon    Samuel

# %%
df1.head()
# Out:
#           last    first               email  age
# index
# one    Chaplin  Charlie   chaplin@gmail.com   89
# two       Does     Jane  JaneDoes@email.com  NaN
# three      Ben    Uncle       ben@email.com  NaN
# four       Oli     K.P.     kpbaa@gmail.com   78
# five       BLC      XYZ   newmail@gmail.com  NaN

# %%
df2=df1
df2.columns
# Out:
# Index(['last', 'first', 'email', 'age'], dtype='object')

# %%
df2['midName']=[x[0] for x in df2['last']]

# %%
df2
# Out:
#             last    first               email  age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com   89       C
# two         Does     Jane  JaneDoes@email.com  NaN       D
# three        Ben    Uncle       ben@email.com  NaN       B
# four         Oli     K.P.     kpbaa@gmail.com   78       O
# five         BLC      XYZ   newmail@gmail.com  NaN       B
# zero    Bhandari      Raj                                B
# newone     White     Snow                                W
# newtwo    Samuel   Marlon                                S

# %%
df4=df2
df4
# Out:
#             last    first               email  age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com   89       C
# two         Does     Jane  JaneDoes@email.com  NaN       D
# three        Ben    Uncle       ben@email.com  NaN       B
# four         Oli     K.P.     kpbaa@gmail.com   78       O
# five         BLC      XYZ   newmail@gmail.com  NaN       B
# zero    Bhandari      Raj                                B
# newone     White     Snow                                W
# newtwo    Samuel   Marlon                                S

# %%
df4[df4.notna()].count()
# Out:
# last       8
# first      8
# email      8
# age        5
# midName    8
# dtype: int64

# %%
df4.dropna()
# Out:
#             last    first              email age midName
# index
# one      Chaplin  Charlie  chaplin@gmail.com  89       C
# four         Oli     K.P.    kpbaa@gmail.com  78       O
# zero    Bhandari      Raj                              B
# newone     White     Snow                              W
# newtwo    Samuel   Marlon                              S

# %%
df4
# Out:
#             last    first               email  age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com   89       C
# two         Does     Jane  JaneDoes@email.com  NaN       D
# three        Ben    Uncle       ben@email.com  NaN       B
# four         Oli     K.P.     kpbaa@gmail.com   78       O
# five         BLC      XYZ   newmail@gmail.com  NaN       B
# zero    Bhandari      Raj                                B
# newone     White     Snow                                W
# newtwo    Samuel   Marlon                                S

# %%
df4.fillna(0)
# Out:
#             last    first               email age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com  89       C
# two         Does     Jane  JaneDoes@email.com   0       D
# three        Ben    Uncle       ben@email.com   0       B
# four         Oli     K.P.     kpbaa@gmail.com  78       O
# five         BLC      XYZ   newmail@gmail.com   0       B
# zero    Bhandari      Raj                               B
# newone     White     Snow                               W
# newtwo    Samuel   Marlon                               S

# %%
df4 = df4.replace(r'^\s*$', np.nan, regex=True) #\s: space/empty, *: 0 or more
df4
# Out:
#             last    first               email   age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com  89.0       C
# two         Does     Jane  JaneDoes@email.com   NaN       D
# three        Ben    Uncle       ben@email.com   NaN       B
# four         Oli     K.P.     kpbaa@gmail.com  78.0       O
# five         BLC      XYZ   newmail@gmail.com   NaN       B
# zero    Bhandari      Raj                 NaN   NaN       B
# newone     White     Snow                 NaN   NaN       W
# newtwo    Samuel   Marlon                 NaN   NaN       S

# %%
df4.email = df4.email.fillna('x@y.z')

# %%
df4
# Out:
#             last    first               email   age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com  89.0       C
# two         Does     Jane  JaneDoes@email.com   NaN       D
# three        Ben    Uncle       ben@email.com   NaN       B
# four         Oli     K.P.     kpbaa@gmail.com  78.0       O
# five         BLC      XYZ   newmail@gmail.com   NaN       B
# zero    Bhandari      Raj               x@y.z   NaN       B
# newone     White     Snow               x@y.z   NaN       W
# newtwo    Samuel   Marlon               x@y.z   NaN       S

# %%
df4.fillna(0)
# Out:
#             last    first               email   age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com  89.0       C
# two         Does     Jane  JaneDoes@email.com   0.0       D
# three        Ben    Uncle       ben@email.com   0.0       B
# four         Oli     K.P.     kpbaa@gmail.com  78.0       O
# five         BLC      XYZ   newmail@gmail.com   0.0       B
# zero    Bhandari      Raj               x@y.z   0.0       B
# newone     White     Snow               x@y.z   0.0       W
# newtwo    Samuel   Marlon               x@y.z   0.0       S

# %%
df4.dtypes
# Out:
# last        object
# first       object
# email       object
# age        float64
# midName     object
# dtype: object

# %%
df4['age'].cumsum()
# Out:
# index
# one        89.0
# two         NaN
# three       NaN
# four      167.0
# five        NaN
# zero        NaN
# newone      NaN
# newtwo      NaN
# Name: age, dtype: float64

# %%
df4
# Out:
#             last    first               email   age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com  89.0       C
# two         Does     Jane  JaneDoes@email.com   NaN       D
# three        Ben    Uncle       ben@email.com   NaN       B
# four         Oli     K.P.     kpbaa@gmail.com  78.0       O
# five         BLC      XYZ   newmail@gmail.com   NaN       B
# zero    Bhandari      Raj               x@y.z   NaN       B
# newone     White     Snow               x@y.z   NaN       W
# newtwo    Samuel   Marlon               x@y.z   NaN       S

# %%
df4.fillna(method='ffill')
# Out:
#             last    first               email   age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com  89.0       C
# two         Does     Jane  JaneDoes@email.com  89.0       D
# three        Ben    Uncle       ben@email.com  89.0       B
# four         Oli     K.P.     kpbaa@gmail.com  78.0       O
# five         BLC      XYZ   newmail@gmail.com  78.0       B
# zero    Bhandari      Raj               x@y.z  78.0       B
# newone     White     Snow               x@y.z  78.0       W
# newtwo    Samuel   Marlon               x@y.z  78.0       S

# %%
df5 = df4.fillna(method='bfill')
df5
# Out:
#             last    first               email   age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com  89.0       C
# two         Does     Jane  JaneDoes@email.com  78.0       D
# three        Ben    Uncle       ben@email.com  78.0       B
# four         Oli     K.P.     kpbaa@gmail.com  78.0       O
# five         BLC      XYZ   newmail@gmail.com   NaN       B
# zero    Bhandari      Raj               x@y.z   NaN       B
# newone     White     Snow               x@y.z   NaN       W
# newtwo    Samuel   Marlon               x@y.z   NaN       S

# %%
val=round(df4['age'].astype(float).mean())
val
# Out:
# 84

# %%
df4['age']=df4['age'].fillna(val)

# %%
df4
# Out:
#             last    first               email   age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com  89.0       C
# two         Does     Jane  JaneDoes@email.com  84.0       D
# three        Ben    Uncle       ben@email.com  84.0       B
# four         Oli     K.P.     kpbaa@gmail.com  78.0       O
# five         BLC      XYZ   newmail@gmail.com  84.0       B
# zero    Bhandari      Raj               x@y.z  84.0       B
# newone     White     Snow               x@y.z  84.0       W
# newtwo    Samuel   Marlon               x@y.z  84.0       S

# %%
df4.sort_values(by='age')
# Out:
#             last    first               email   age midName
# index
# four         Oli     K.P.     kpbaa@gmail.com  78.0       O
# two         Does     Jane  JaneDoes@email.com  84.0       D
# three        Ben    Uncle       ben@email.com  84.0       B
# five         BLC      XYZ   newmail@gmail.com  84.0       B
# zero    Bhandari      Raj               x@y.z  84.0       B
# newone     White     Snow               x@y.z  84.0       W
# newtwo    Samuel   Marlon               x@y.z  84.0       S
# one      Chaplin  Charlie   chaplin@gmail.com  89.0       C

# %%
df4['age'].value_counts()
# Out:
# 84.0    6
# 89.0    1
# 78.0    1
# Name: age, dtype: int64

# %%
df5
# Out:
#             last    first               email   age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com  89.0       C
# two         Does     Jane  JaneDoes@email.com  78.0       D
# three        Ben    Uncle       ben@email.com  78.0       B
# four         Oli     K.P.     kpbaa@gmail.com  78.0       O
# five         BLC      XYZ   newmail@gmail.com   NaN       B
# zero    Bhandari      Raj               x@y.z   NaN       B
# newone     White     Snow               x@y.z   NaN       W
# newtwo    Samuel   Marlon               x@y.z   NaN       S

# %%
l=list(df5.index[df5.age>50])
l
# Out:
# ['one', 'two', 'three', 'four']

# %%
df5.loc[l,'age']=60

# %%
df5
# Out:
#             last    first               email   age midName
# index
# one      Chaplin  Charlie   chaplin@gmail.com  60.0       C
# two         Does     Jane  JaneDoes@email.com  60.0       D
# three        Ben    Uncle       ben@email.com  60.0       B
# four         Oli     K.P.     kpbaa@gmail.com  60.0       O
# five         BLC      XYZ   newmail@gmail.com   NaN       B
# zero    Bhandari      Raj               x@y.z   NaN       B
# newone     White     Snow               x@y.z   NaN       W
# newtwo    Samuel   Marlon               x@y.z   NaN       S

# %%
df5.age
# Out:
# index
# one       60.0
# two       60.0
# three     60.0
# four      60.0
# five       NaN
# zero       NaN
# newone     NaN
# newtwo     NaN
# Name: age, dtype: float64

# %%
df5.index[df5.age<50]
# Out:
# Index([], dtype='object', name='index')

# %%
df5.lo;[['five','zero','newone','newtwo']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b1a1ffb69411> in <module>
# ----> 1 df5.lo;[['five','zero','newone','newtwo']]
#
# NameError: name 'df5' is not defined

# %%
import pandas as pd

# %%
people = {
    "first": ["Charlie", 'Jane', 'Uncle'], 
    "last": ["Chaplin", 'Does', 'Ben'], 
    "email": ["chaplin@gmail.com", 'JaneDoes@email.com', 'ben@email.com']
}
df1=pd.DataFrame(people)
df1
# Out:
#      first     last               email
# 0  Charlie  Chaplin   chaplin@gmail.com
# 1     Jane     Does  JaneDoes@email.com
# 2    Uncle      Ben       ben@email.com

# %%
people2 = {
    "first": ["Charlie", 'Jane', 'Uncle'], 
    "age": [30, 40, 50], 
    "country": ["USA", 'Trinidad', 'UK']
}
df2=pd.DataFrame(people2)
df2
# Out:
#      first  age   country
# 0  Charlie   30       USA
# 1     Jane   40  Trinidad
# 2    Uncle   50        UK

# %%
final = df1.merge(df2,on='first')

# %%
final
# Out:
#      first     last               email  age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   30       USA
# 1     Jane     Does  JaneDoes@email.com   40  Trinidad
# 2    Uncle      Ben       ben@email.com   50        UK

# %%
finalNew = pd.concat([df1,df2])
finalNew
# Out:
#      first     last               email   age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   NaN       NaN
# 1     Jane     Does  JaneDoes@email.com   NaN       NaN
# 2    Uncle      Ben       ben@email.com   NaN       NaN
# 0  Charlie      NaN                 NaN  30.0       USA
# 1     Jane      NaN                 NaN  40.0  Trinidad
# 2    Uncle      NaN                 NaN  50.0        UK

# %%
xyz=finalNew
xyz.T
# Out:
#                          0                   1              2        0  \
# first              Charlie                Jane          Uncle  Charlie
# last               Chaplin                Does            Ben      NaN
# email    chaplin@gmail.com  JaneDoes@email.com  ben@email.com      NaN
# age                    NaN                 NaN            NaN     30.0
# country                NaN                 NaN            NaN      USA
#
#                 1      2
# first        Jane  Uncle
# last          NaN    NaN
# email         NaN    NaN
# age          40.0   50.0
# country  Trinidad     UK

# %%
xyz.T.
