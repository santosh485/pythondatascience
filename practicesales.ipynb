# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
sales = pd.read_csv("sample-salesv2.csv")
sales
# Out:
#      account number                           name       sku category  \
# 0            296809                    Carroll PLC  QN-82852     Belt
# 1             98022              Heidenreich-Bosco  MJ-21460    Shoes
# 2            563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt
# 3             93356                  Waters-Walker  AS-93055    Shirt
# 4            659366                  Waelchi-Fahey  AS-93055    Shirt
# ..              ...                            ...       ...      ...
# 995          758133      Kihn, McClure and Denesik  WJ-02096     Belt
# 996          850140                      Kunze Inc  GS-86623    Shoes
# 997           93356                  Waters-Walker  GS-86623    Shoes
# 998          304860                      Huel-Haag  LL-46261    Shoes
# 999           98022              Heidenreich-Bosco  LW-86841    Shoes
#
#      quantity  unit price  ext price              date
# 0          13       44.48     578.24    9/27/2014 7:13
# 1          19       53.62    1018.78    7/29/2014 2:10
# 2          12       24.16     289.92    3/1/2014 10:51
# 3           5       82.68     413.40  11/17/2013 20:41
# 4          18       99.64    1793.52     1/3/2014 8:14
# ..        ...         ...        ...               ...
# 995        11       60.50     665.50    8/3/2014 10:39
# 996        16       19.66     314.56    5/3/2014 21:18
# 997        13       90.95    1182.35   6/14/2014 12:43
# 998         9       98.22     883.98    7/26/2014 1:10
# 999        14       74.83    1047.62    6/27/2014 5:58
#
# [1000 rows x 8 columns]

# %%
sales.dtypes
# Out:
# account number      int64
# name               object
# sku                object
# category           object
# quantity            int64
# unit price        float64
# ext price         float64
# date               object
# dtype: object

# %%
type(sales)
# Out:
# pandas.core.frame.DataFrame

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   account number  1000 non-null   int64
#  1   name            1000 non-null   object
#  2   sku             1000 non-null   object
#  3   category        1000 non-null   object
#  4   quantity        1000 non-null   int64
#  5   unit price      1000 non-null   float64
#  6   ext price       1000 non-null   float64
#  7   date            1000 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 62.6+ KB

# %%
sales.describe()
# Out:
#        account number     quantity   unit price   ext price
# count     1000.000000  1000.000000  1000.000000  1000.00000
# mean    535208.897000    10.328000    56.179630   579.84390
# std     277589.746014     5.687597    25.331939   435.30381
# min      93356.000000     1.000000    10.060000    10.38000
# 25%     299771.000000     5.750000    35.995000   232.60500
# 50%     563905.000000    10.000000    56.765000   471.72000
# 75%     750461.000000    15.000000    76.802500   878.13750
# max     995267.000000    20.000000    99.970000  1994.80000

# %%
sales.describe(include='all',datetime_is_numeric=True)
# Out:
#         account number                           name       sku category  \
# count      1000.000000                           1000      1000     1000
# unique             NaN                             20        10        3
# top                NaN  Senger, Upton and Breitenberg  QN-82852    Shirt
# freq               NaN                             59       109      404
# mean     535208.897000                            NaN       NaN      NaN
# std      277589.746014                            NaN       NaN      NaN
# min       93356.000000                            NaN       NaN      NaN
# 25%      299771.000000                            NaN       NaN      NaN
# 50%      563905.000000                            NaN       NaN      NaN
# 75%      750461.000000                            NaN       NaN      NaN
# max      995267.000000                            NaN       NaN      NaN
#
#            quantity   unit price   ext price            date
# count   1000.000000  1000.000000  1000.00000            1000
# unique          NaN          NaN         NaN             998
# top             NaN          NaN         NaN  2/15/2014 6:51
# freq            NaN          NaN         NaN               2
# mean      10.328000    56.179630   579.84390             NaN
# std        5.687597    25.331939   435.30381             NaN
# min        1.000000    10.060000    10.38000             NaN
# 25%        5.750000    35.995000   232.60500             NaN
# 50%       10.000000    56.765000   471.72000             NaN
# 75%       15.000000    76.802500   878.13750             NaN
# max       20.000000    99.970000  1994.80000             NaN

# %%
sales[['account number','name','sku','category','quantity','unit price']]
# Out:
#      account number                           name       sku category  \
# 0            296809                    Carroll PLC  QN-82852     Belt
# 1             98022              Heidenreich-Bosco  MJ-21460    Shoes
# 2            563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt
# 3             93356                  Waters-Walker  AS-93055    Shirt
# 4            659366                  Waelchi-Fahey  AS-93055    Shirt
# ..              ...                            ...       ...      ...
# 995          758133      Kihn, McClure and Denesik  WJ-02096     Belt
# 996          850140                      Kunze Inc  GS-86623    Shoes
# 997           93356                  Waters-Walker  GS-86623    Shoes
# 998          304860                      Huel-Haag  LL-46261    Shoes
# 999           98022              Heidenreich-Bosco  LW-86841    Shoes
#
#      quantity  unit price
# 0          13       44.48
# 1          19       53.62
# 2          12       24.16
# 3           5       82.68
# 4          18       99.64
# ..        ...         ...
# 995        11       60.50
# 996        16       19.66
# 997        13       90.95
# 998         9       98.22
# 999        14       74.83
#
# [1000 rows x 6 columns]

# %%
list(sales['name'].unique())
# Out:
# ['Carroll PLC',
#  'Heidenreich-Bosco',
#  'Kerluke, Reilly and Bechtelar',
#  'Waters-Walker',
#  'Waelchi-Fahey',
#  'Cole-Eichmann',
#  'Hegmann and Sons',
#  'Senger, Upton and Breitenberg',
#  'Kihn, McClure and Denesik',
#  'Ernser, Cruickshank and Lind',
#  'Koelpin PLC',
#  'Volkman, Goyette and Lemke',
#  'Berge LLC',
#  'Huel-Haag',
#  'Kunze Inc',
#  'Gorczany-Hahn',
#  'Kilback-Gerlach',
#  'Hamill-Hackett',
#  'Davis, Kshlerin and Reilly',
#  'Kuphal, Zieme and Kub']

# %%
sales['category'].unique()
# Out:
# array(['Belt', 'Shoes', 'Shirt'], dtype=object)

# %%
sales[sales['name'].str.contains('C')][::10]
# Out:
#      account number                          name       sku category  \
# 0            296809                   Carroll PLC  QN-82852     Belt
# 24           296809                   Carroll PLC  AS-93055    Shirt
# 54           201259                   Koelpin PLC  FK-71853    Shirt
# 87           734922                     Berge LLC  LW-86841    Shoes
# 116          555594  Ernser, Cruickshank and Lind  MJ-21460    Shoes
# 152          201259                   Koelpin PLC  LW-86841    Shoes
# 187          758133     Kihn, McClure and Denesik  VG-32047    Shirt
# 221          555594  Ernser, Cruickshank and Lind  WJ-02096     Belt
# 237          758133     Kihn, McClure and Denesik  GS-86623    Shoes
# 275          555594  Ernser, Cruickshank and Lind  KV-99194    Shirt
# 317          734922                     Berge LLC  LW-86841    Shoes
# 337          555594  Ernser, Cruickshank and Lind  MJ-21460    Shoes
# 366          995267                 Cole-Eichmann  QN-82852     Belt
# 406          201259                   Koelpin PLC  GS-86623    Shoes
# 445          296809                   Carroll PLC  KV-99194    Shirt
# 477          734922                     Berge LLC  FK-71853    Shirt
# 510          201259                   Koelpin PLC  WJ-02096     Belt
# 554          296809                   Carroll PLC  WJ-02096     Belt
#
#      ext price             date
# 0       578.24   9/27/2014 7:13
# 120    1293.12   8/19/2014 0:53
# 242     260.80    4/5/2014 2:00
# 339     207.90   3/29/2014 8:13
# 461     164.36  8/24/2014 20:22
# 575     439.70  10/3/2014 17:04
# 661    1328.60  12/30/2013 9:47
# 796     411.76   1/9/2014 11:37
# 893    1468.32  2/23/2014 18:10

# %%
sales[sales['category'].str.startswith('S')]
# Out:
#      account number                           name       sku category  \
# 1             98022              Heidenreich-Bosco  MJ-21460    Shoes
# 2            563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt
# 3             93356                  Waters-Walker  AS-93055    Shirt
# 4            659366                  Waelchi-Fahey  AS-93055    Shirt
# 5            563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt
# ..              ...                            ...       ...      ...
# 993          659366                  Waelchi-Fahey  LW-86841    Shoes
# 996          850140                      Kunze Inc  GS-86623    Shoes
# 997           93356                  Waters-Walker  GS-86623    Shoes
# 998          304860                      Huel-Haag  LL-46261    Shoes
# 999           98022              Heidenreich-Bosco  LW-86841    Shoes
#
#      quantity  unit price  ext price              date
# 1          19       53.62    1018.78    7/29/2014 2:10
# 2          12       24.16     289.92    3/1/2014 10:51
# 3           5       82.68     413.40  11/17/2013 20:41
# 4          18       99.64    1793.52     1/3/2014 8:14
# 5          17       52.82     897.94    12/4/2013 2:07
# ..        ...         ...        ...               ...
# 993        10       56.56     565.60   10/1/2014 11:38
# 996        16       19.66     314.56    5/3/2014 21:18
# 997        13       90.95    1182.35   6/14/2014 12:43
# 998         9       98.22     883.98    7/26/2014 1:10
# 999        14       74.83    1047.62    6/27/2014 5:58
#
# [804 rows x 8 columns]

# %%
sales[sales['category'].str.startswith('S')].style.bar(subset=['quantity'])
# Out:
# <style  type="text/css" >
# #T_e598c_row0_col4,#T_e598c_row9_col4,#T_e598c_row78_col4,#T_e598c_row81_col4,#T_e598c_row85_col4,#T_e598c_row88_col4,#T_e598c_row144_col4,#T_e598c_row199_col4,#T_e598c_row221_col4,#T_e598c_row224_col4,#T_e598c_row233_col4,#T_e598c_row313_col4,#T_e598c_row394_col4,#T_e598c_row401_col4,#T_e598c_row425_col4,#T_e598c_row447_col4,#T_e598c_row449_col4,#T_e598c_row479_col4,#T_e598c_row489_col4,#T_e598c_row509_col4,#T_e598c_row522_col4,#T_e598c_row537_col4,#T_e598c_row545_col4,#T_e598c_row557_col4,#T_e598c_row599_col4,#T_e598c_row607_col4,#T_e598c_row609_col4,#T_e598c_row674_col4,#T_e598c_row675_col4,#T_e598c_row696_col4,#T_e598c_row698_col4,#T_e598c_row722_col4,#T_e598c_row729_col4,#T_e598c_row752_col4,#T_e598c_row775_col4,#T_e598c_row784_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 94.7%, transparent 94.7%);
col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.8%, transparent 15.8%);
#         }#T_e598c_row12_col4,#T_e598c_row54_col4,#T_e598c_row66_col4,#T_e598c_row86_col4,#T_e598c_row97_col4,#T_e598c_row108_col4,#T_e598c_row134_col4,#T_e598c_row160_col4,#T_e598c_row178_col4,#T_e598c_row198_col4,#T_e598c_row203_col4,#T_e598c_row205_col4,#T_e598c_row225_col4,#T_e598c_row231_col4,#T_e598c_row238_col4,#T_e598c_row241_col4,#T_e598c_row242_col4,#T_e598c_row324_col4,#T_e598c_row338_col4,#T_e598c_row341_col4,#T_e598c_row354_col4,#T_e598c_row360_col4,#T_e598c_row382_col4,#T_e598c_row388_col4,#T_e598c_row467_col4,#T_e598c_row472_col4,#T_e598c_row517_col4,#T_e598c_row547_col4,#T_e598c_row548_col4,#T_e598c_row554_col4,#T_e598c_row572_col4,#T_e598c_row597_col4,#T_e598c_row617_col4,#T_e598c_row650_col4,#T_e598c_row658_col4,#T_e598c_row670_col4,#T_e598c_row727_col4,#T_e598c_row745_col4,#T_e598c_row747_col4,#T_e598c_row769_col4,#T_e598c_row786_col4,#T_e598c_row797_col4,#T_e598c_row798_col4,#T_e598c_row802_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 42.1%, transparent 42.1%);
#         }#T_e598c_row17_col4,#T_e598c_row24_col4,#T_e598c_row76_col4,#T_e598c_row83_col4,#T_e598c_row98_col4,#T_e598c_row115_col4,#T_e598c_row117_col4,#T_e598c_row123_col4,#T_e598c_row132_col4,#T_e598c_row154_col4,#T_e598c_row156_col4,#T_e598c_ro

# %%
customers = sales

# %%
customer_group = customers.groupby('name')

# %%
sales_totals = customer_group.sum()

# %%
sales_totals
# Out:
#                                account number  quantity  unit price  ext price
# name
# Berge LLC                            38215944       522     3076.92   30064.87
# Carroll PLC                          16918113       677     2947.25   35934.31
# Cole-Eichmann                        50758617       538     2833.00   30435.42
# Davis, Kshlerin and Reilly           12537923       379     2138.16   19054.76
# Ernser, Cruickshank and Lind         26112918       455     2854.91   28089.02
# Gorczany-Hahn                         4835796       440     2225.71   22207.90
# Hamill-Hackett                       29781268       419     2582.64   23433.78
# Hegmann and Sons                     30393218       606     3413.61   35213.72
# Heidenreich-Bosco                     3920880       431     2322.30   25428.29
# Huel-Haag                            13108980       358     2498.97   21087.88
# Kerluke, Reilly and Bechtelar        29323060       556     2578.55   27389.43
# Kihn, McClure and Denesik            43971714       638     3487.45   38935.29
# Kilback-Gerlach                      32037795       472     2650.98   26987.20
# Koelpin PLC                          10666727       497     2687.66   26811.66
# Kunze Inc                            45907560       605     3025.18   34406.54
# Kuphal, Zieme and Kub                15588092       552     2678.55   27031.86
# Senger, Upton and Breitenberg        54834600       566     3023.81   29577.46
# Volkman, Goyette and Lemke           36022128       538     2832.62   32006.87
# Waelchi-Fahey                        35605764       501     3017.41   28968.68
# Waters-Walker                         4667800       578     3303.95   36778.96

# %%
len(sales_totals)
# Out:
# 20

# %%
type(sales_totals)
# Out:
# pandas.core.frame.DataFrame

# %%
sales_totals.loc['Carroll PLC']['ext price']
# Out:
# 35934.30999999999

# %%
sales_totals.filter(regex='^K',axis=0)
# Out:
#                                account number  quantity  unit price  ext price
# name
# Kerluke, Reilly and Bechtelar        29323060       556     2578.55   27389.43
# Kihn, McClure and Denesik            43971714       638     3487.45   38935.29
# Kilback-Gerlach                      32037795       472     2650.98   26987.20
# Koelpin PLC                          10666727       497     2687.66   26811.66
# Kunze Inc                            45907560       605     3025.18   34406.54
# Kuphal, Zieme and Kub                15588092       552     2678.55   27031.86

# %%
sales_totals.T
# Out:
# name              Berge LLC  Carroll PLC  Cole-Eichmann  \
# account number  38215944.00  16918113.00    50758617.00
# quantity             522.00       677.00         538.00
# unit price          3076.92      2947.25        2833.00
# ext price          30064.87     35934.31       30435.42
#
# name            Davis, Kshlerin and Reilly  Ernser, Cruickshank and Lind  \
# account number                 12537923.00                   26112918.00
# quantity                            379.00                        455.00
# unit price                         2138.16                       2854.91
# ext price                         19054.76                      28089.02
#
# name            Gorczany-Hahn  Hamill-Hackett  Hegmann and Sons  \
# account number     4835796.00     29781268.00       30393218.00
# quantity               440.00          419.00            606.00
# unit price            2225.71         2582.64           3413.61
# ext price            22207.90        23433.78          35213.72
#
# name            Heidenreich-Bosco    Huel-Haag  Kerluke, Reilly and Bechtelar  \
# account number         3920880.00  13108980.00                    29323060.00
# quantity                   431.00       358.00                         556.00
# unit price                2322.30      2498.97                        2578.55
# ext price                25428.29     21087.88                       27389.43
#
# name            Kihn, McClure and Denesik  Kilback-Gerlach  Koelpin PLC  \
# account number                43971714.00      32037795.00  10666727.00
# quantity                           638.00           472.00       497.00
# unit price                        3487.45          2650.98      2687.66
# ext price                        38935.29         26987.20     26811.66
#
# name              Kunze Inc  Kuphal, Zieme and Kub  \
# account number  45907560.00            15588092.00
# quantity             605.00                 552.00
# unit price          3025.18                2678.55
# ext price          34406.54               27031.86
#
# name            Senger, Upton and Breitenberg  Volkman, Goyette and Lemke  \
# account number                    54834600.00                 36022128.00
# quantity                               566.00                      538.00
# unit price                            3023.81                     2832.62
# ext price                            29577.46                    32006.87
#
# name            Waelchi-Fahey  Waters-Walker
# account number    35605764.00     4667800.00
# quantity               501.00         578.00
# unit price            3017.41        3303.95
# ext price            28968.68       36778.96

# %%
import re
[values for index,values in enumerate(sales_totals.index) if re.search(r'H[a-z]+',values)]
# Out:
# ['Gorczany-Hahn',
#  'Hamill-Hackett',
#  'Hegmann and Sons',
#  'Heidenreich-Bosco',
#  'Huel-Haag']

# %%
sales_totals.loc[[values for index,values in enumerate(sales_totals.index) if re.search(r'H[a-z]+',values)]]
# Out:
#                    account number  quantity  unit price  ext price
# name
# Gorczany-Hahn             4835796       440     2225.71   22207.90
# Hamill-Hackett           29781268       419     2582.64   23433.78
# Hegmann and Sons         30393218       606     3413.61   35213.72
# Heidenreich-Bosco         3920880       431     2322.30   25428.29
# Huel-Haag                13108980       358     2498.97   21087.88

# %%
bar_plot = sales_totals.plot(kind='bar',legend=None,title="Total Sales by Customer",figsize=(16,7)) #16,7 (x,y): cm, inch??
bar_plot.set_xlabel("Customers")
bar_plot.set_ylabel("Sales ($)")
plt.show()

# %%
customers = sales[['name','category','ext price','date']]
customers.head(5)
# Out:
#                             name category  ext price              date
# 0                    Carroll PLC     Belt     578.24    9/27/2014 7:13
# 1              Heidenreich-Bosco    Shoes    1018.78    7/29/2014 2:10
# 2  Kerluke, Reilly and Bechtelar    Shirt     289.92    3/1/2014 10:51
# 3                  Waters-Walker    Shirt     413.40  11/17/2013 20:41
# 4                  Waelchi-Fahey    Shirt    1793.52     1/3/2014 8:14

# %%
category_group = customers.groupby(['name','category']).sum()  #'date'

# %%
category_group.T
# Out:
# name      Berge LLC                   Carroll PLC                      \
# category       Belt    Shirt    Shoes        Belt     Shirt     Shoes
# ext price   6033.53  9670.24  14361.1     9359.26  13717.61  12857.44
#
# name      Cole-Eichmann                    Davis, Kshlerin and Reilly  ...  \
# category           Belt     Shirt    Shoes                       Belt  ...
# ext price        8112.7  14528.01  7794.71                    1604.13  ...
#
# name      Senger, Upton and Breitenberg Volkman, Goyette and Lemke            \
# category                          Shoes                       Belt     Shirt
# ext price                      12407.88                    4429.01  12791.27
#
# name                Waelchi-Fahey                    Waters-Walker            \
# category      Shoes          Belt     Shirt    Shoes          Belt     Shirt
# ext price  14786.59       8285.72  11689.05  8993.91       5957.24  18633.71
#
# name
# category      Shoes
# ext price  12188.01
#
# [1 rows x 60 columns]

# %%
category_group.tail(20)
# Out:
#                                         ext price
# name                          category
# Koelpin PLC                   Shirt       7908.28
#                               Shoes      13575.42
# Kunze Inc                     Belt        4264.59
#                               Shirt      15638.87
#                               Shoes      14503.08
# Kuphal, Zieme and Kub         Belt        2009.69
#                               Shirt      12101.14
#                               Shoes      12921.03
# Senger, Upton and Breitenberg Belt        9509.88
#                               Shirt       7659.70
#                               Shoes      12407.88
# Volkman, Goyette and Lemke    Belt        4429.01
#                               Shirt      12791.27
#                               Shoes      14786.59
# Waelchi-Fahey                 Belt        8285.72
#                               Shirt      11689.05
#                               Shoes       8993.91
# Waters-Walker                 Belt        5957.24
#                               Shirt      18633.71
#                               Shoes      12188.01

# %%
category_group.unstack()
# Out:
#                               ext price
# category                           Belt     Shirt     Shoes
# name
# Berge LLC                       6033.53   9670.24  14361.10
# Carroll PLC                     9359.26  13717.61  12857.44
# Cole-Eichmann                   8112.70  14528.01   7794.71
# Davis, Kshlerin and Reilly      1604.13   7533.03   9917.60
# Ernser, Cruickshank and Lind    5894.38  16944.19   5250.45
# Gorczany-Hahn                   3642.48  12576.83   5988.59
# Hamill-Hackett                  1609.74   8880.04  12944.00
# Hegmann and Sons                4909.38  16774.47  13529.87
# Heidenreich-Bosco               6262.94   5965.25  13200.10
# Huel-Haag                       2219.51  11944.01   6924.36
# Kerluke, Reilly and Bechtelar   4102.11  12958.23  10329.09
# Kihn, McClure and Denesik      10116.90  18956.35   9862.04
# Kilback-Gerlach                 2863.40   9904.85  14218.95
# Koelpin PLC                     5327.96   7908.28  13575.42
# Kunze Inc                       4264.59  15638.87  14503.08
# Kuphal, Zieme and Kub           2009.69  12101.14  12921.03
# Senger, Upton and Breitenberg   9509.88   7659.70  12407.88
# Volkman, Goyette and Lemke      4429.01  12791.27  14786.59
# Waelchi-Fahey                   8285.72  11689.05   8993.91
# Waters-Walker                   5957.24  18633.71  12188.01

# %%
stack_bar_plot = category_group.unstack().plot(kind='bar',stacked=True,title="Total Sales by Customer (categorical)",figsize=(15,7))
#stack_bar_plot = category_group.unstack().plot(kind='bar',title="Total Sales by Customer",figsize=(16,7))
stack_bar_plot.set_xlabel("Customers")
stack_bar_plot.set_ylabel("Sales")
stack_bar_plot.legend(["Belts","Shirts","Shoes"])#, loc=1,ncol=3)
plt.show()

# %%
# Create a simple histogram of purchase volumes

# Plot Overview ????  

purchase_patterns = sales[['ext price','category','date']] #TEST: exp price <=300


#purchase_patterns = sales[sales['ext price']<=300][['category','ext price']]
#purchase_patterns = sales[sales['ext price']<=300]['category']

#purchase_patterns = sales[sales['ext price']<=300][ [columnName1,columnName2] ]

#len(purchase_patterns)
#purchase_patterns.count()
purchase_patterns.head(10)
# Out:
#    ext price category              date
# 0     578.24     Belt    9/27/2014 7:13
# 1    1018.78    Shoes    7/29/2014 2:10
# 2     289.92    Shirt    3/1/2014 10:51
# 3     413.40    Shirt  11/17/2013 20:41
# 4    1793.52    Shirt     1/3/2014 8:14
# 5     897.94    Shirt    12/4/2013 2:07
# 6     275.04    Shoes    4/9/2014 16:15
# 7     551.46    Shoes   6/18/2014 19:25
# 8     649.23    Shoes    2/10/2014 5:55
# 9     323.76    Shirt    5/20/2014 0:21

# %%
purchase_plot = purchase_patterns['ext price'].hist(bins=50,figsize=(16,7))  #Distribution: min-max > range (TASK: bin?)
purchase_plot.set_title("Purchase Patterns")
purchase_plot.set_xlabel("Order Amount($)")
purchase_plot.set_ylabel("Number of orders")
plt.show()

# %%
purchase_patterns['ext price'][::5].plot(figsize=(16,7))
# Out:
# <AxesSubplot:>

# %%
# Create a line chart showing purchases by month

purchase_pattern = purchase_patterns.set_index('date')
purchase_pattern.head()
# Out:
#                   ext price category
# date
# 9/27/2014 7:13       578.24     Belt
# 7/29/2014 2:10      1018.78    Shoes
# 3/1/2014 10:51       289.92    Shirt
# 11/17/2013 20:41     413.40    Shirt
# 1/3/2014 8:14       1793.52    Shirt

# %%
purchase_pattern.loc['2013/10/01':'2013/11/30'].plot(figsize=(16,7))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Other\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: '2013/10/01'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-8e73f646c0b7> in <module>
# ----> 1 purchase_pattern.loc['2013/10/01':'2013/11/30'].plot(figsize=(16,7))
#
# D:\Other\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# D:\Other\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1100         if isinstance(key, slice):
#    1101             self._validate_key(key, axis)
# -> 1102             return self._get_slice_axis(key, axis=axis)
#    1103         elif com.is_bool_indexer(key):
#    1104             return self._getbool_axis(key, axis=axis)
#
# D:\Other\anaconda\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1134
#    1135         labels = obj._get_axis(axis)
# -> 1136         indexer = labels.slice_indexer(
#    1137             slice_obj.start, slice_obj.stop, slice_obj.step, kind="loc"
#    1138         )
#
# D:\Other\anaconda\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    5275         slice(1, 3, None)
#    5276         """
# -> 5277         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    5278
#    5279         # return a slice
#
# D:\Other\anaconda\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    5474         start_slice = None
#    5475         if start is not None:
# -> 5476             start_slice = self.get_slice_bound(start, "left", kind)
#    5477         if start_slice is None:
#    5478             start_slice = 0
#
# D:\Other\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5394             except ValueError:
#    5395                 # raise the original KeyError
# -> 5396                 raise err
#    5397
#    5398         if isinstance(slc, np.ndarray):
#
# D:\Other\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5388         # we need to look up the label
#    5389         try:
# -> 5390             slc = self.get_loc(label)
#    5391         except KeyError as err:
#    5392             try:
#
# D:\Other\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '2013/10/01'

# %%
pivotFilter.query("category==['Shoes']")['sum','ext price'].plot(kind='bar',figsize=(16,7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-7b32c034279e> in <module>
# ----> 1 pivotFilter.query("category==['Shoes']")['sum','ext price'].plot(kind='bar',figsize=(16,7))
#
# NameError: name 'pivotFilter' is not defined
