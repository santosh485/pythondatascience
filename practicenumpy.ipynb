# %%
import numpy as np

# %%
print(math.sqrt(25))
# Out:
# 5.0

# %%
my_list1 = [1,2,3,4]

# %%
my_array1 = np.array(my_list1)

# %%
my_array1
# Out:
# array([1, 2, 3, 4])

# %%
print(my_array1.shape)
# Out:
# (4,)

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
ages=list(range(17,68,2))
salary=list(range(20000,75000,2199))
exp=list(range(3000,30500,1059))

#unpacking: tuple
t=(1,2,3)
x,y,z=t

print("Total: ages= ",len(ages),' and salary= ',len(salary))
print("Ages")
print(ages[0::3])
print("Salary")
print(salary[0::3])

print("Expenses ",len(exp))
print(exp[0::3])
# Out:
# Total: ages=  26  and salary=  26
# Ages
# [17, 23, 29, 35, 41, 47, 53, 59, 65]
# Salary
# [20000, 26597, 33194, 39791, 46388, 52985, 59582, 66179, 72776]
# Expenses  26
# [3000, 6177, 9354, 12531, 15708, 18885, 22062, 25239, 28416]

# %%
labels = 'Frogs', 'Hogs', 'Dogs'
sizes = np.array([5860, 677, 3200])
colors = ['yellowgreen', 'gold', 'lightskyblue']
#[#66ccff,]

#plt.pie(sizes, labels=labels, colors=colors,autopct="%d%%", shadow=True)
p,t,a = plt.pie(sizes, labels=labels, colors=colors, autopct="", shadow=True)
print(a)

'''
a[0].set_text(sizes[0]) #annotate: set_annotate
a[1].set_text(sizes[1])
a[2].set_text(sizes[2])
'''
for i, x in enumerate(a):
    x.set_text("{}".format(sizes[i]))

plt.axis('equal')
plt.show()
# Out:
# [Text(-0.188684351399663, 0.5695596681093987, ''), Text(-0.39226426413680643, -0.4540140384186482, ''), Text(0.3076232974777665, -0.5151387258291746, '')]

# %%
plt.xkcd()
#plt.style.use('ggplot')
#plt.plot(ages,salary)  #values along: x, y! (28416,72776)
plt.plot(exp)#,salary)
plt.show() #Display the figure

# %%
plt.plot(ages,exp)
plt.plot(ages,salary)
plt.show()

# %%
plt.figure(figsize=(16,10)) #setting figure size! TASK: (10,6)??

'''
linestyle: '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

# Colors:
# Blue = #008fd5
# Red = #fc4f30
# Yellow = #e5ae37
# Green = #6d904f
#black: k
'''
plt.plot(ages,salary,'k-^') #or plt.plot(ages,salary,'r--')
#plt.plot(ages,salary,color='r',linestyle='--') #or plt.plot(ages,salary,'r--')
#plt.plot(ages,exp,'r',linestyle='--') #ro,bo,y-^
plt.plot(ages,exp,'o') #ro,bo,y-^
plt.show()

# %%
plt.pie(salary,labels=salary)
plt.legend()
#plt.grid(True)
plt.show()

# %%
print(matplotlib.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-01a4881bf885> in <module>
# ----> 1 print(matplotlib.__version__)
#
# NameError: name 'matplotlib' is not defined

# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.4.2

# %%
xpoints = np.array([0,6])
ypoints = np.array([0, 250])

# %%
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r', ms = 20, mec = 'b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
plt.plot(ypoints, ls = ':')

# %%
plt.plot(ypoints, color = 'r', linewidth = '20')

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
plt.plot(y1)
plt.plot(y2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1,1,1)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.scatter(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
plt.show()

# %%
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.random.randint(100, size=(100))

plt.scatter(x, y, s=sizes, alpha=0.5, cmap='virdis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y, color = 'red')
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array([35, 25, 25, 15])
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x1be6ad3ed30>,
# ...
#  [Text(0.4993895680663529, 0.9801071672559597, ''),
#   Text(-1.086457168210212, 0.17207795223283895, ''),
#   Text(-0.172077952232839, -1.086457168210212, ''),
#   Text(0.9801071672559598, -0.4993895680663526, '')])

# %%
import matplotlib.pyplot as plt
import numpy as np
myexplode = [0.2, 0, 0, 0]

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, explode = myexplode, shadow = True, labels = mylabels)
plt.legend(title = 'Four Fruits')
plt.show()

# %%
import pandas

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
myvar = pd.Series(a, index = ['x', 'y', 'z'])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df) 
df.loc[0]
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
df = pd.read_csv('earthquake.csv')
df
df.to_string()
df
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 0       85.39    27.58        Lalitpur  14:45        4.1  2015/06/26
# 1       85.49    27.94  Sindhupalchowk  23:51        4.2  2015/06/25
# 2       86.21    27.66         Dolakha  23:49        4.1  2015/06/25
# 3       85.17    27.78         Nuwakot  21:07        4.3  2015/06/25
# 4       85.75    27.85  Sindhupalchowk  14:59        4.0  2015/06/24
# ..        ...      ...             ...    ...        ...         ...
# 438     85.35    28.05          Rasuwa  01:49        4.0  2015/04/26
# 439     85.56    27.93  Sindhupalchowk  01:29        4.1  2015/04/26
# 440     85.43    27.71       Kathmandu  00:43        4.6  2015/04/26
# 441     85.55    27.94  Sindhupalchowk  00:14        4.1  2015/04/26
# 442     85.98    27.78  Sindhupalchowk  23:46        4.1  2015/04/25
#
# [443 rows x 6 columns]

# %%
df.head(10)
# Out:
#   Longitude Latitude       Epicentre   Time  Magnitude        Date
# 0     85.39    27.58        Lalitpur  14:45        4.1  2015/06/26
# 1     85.49    27.94  Sindhupalchowk  23:51        4.2  2015/06/25
# 2     86.21    27.66         Dolakha  23:49        4.1  2015/06/25
# 3     85.17    27.78         Nuwakot  21:07        4.3  2015/06/25
# 4     85.75    27.85  Sindhupalchowk  14:59        4.0  2015/06/24
# 5     86.17    27.67         Dolakha  13:19        4.0  2015/06/22
# 6     86.00    27.80  Sindhupalchowk  19:26        4.3  2015/06/21
# 7     84.94    28.17          Gorkha   2:40        4.2  2015/06/20
# 8     82.76    28.65           Rukum  12:23        5.4  2015/06/20
# 9     84.92    28.26          Gorkha  13:50        4.0  2015/06/19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Longitude  443 non-null    object
#  1   Latitude   443 non-null    object
#  2   Epicentre  443 non-null    object
#  3   Time       443 non-null    object
#  4   Magnitude  443 non-null    float64
#  5   Date       443 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 20.9+ KB

# %%
new_df = df.dropna()

# %%
new_df
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 0       85.39    27.58        Lalitpur  14:45        4.1  2015/06/26
# 1       85.49    27.94  Sindhupalchowk  23:51        4.2  2015/06/25
# 2       86.21    27.66         Dolakha  23:49        4.1  2015/06/25
# 3       85.17    27.78         Nuwakot  21:07        4.3  2015/06/25
# 4       85.75    27.85  Sindhupalchowk  14:59        4.0  2015/06/24
# ..        ...      ...             ...    ...        ...         ...
# 438     85.35    28.05          Rasuwa  01:49        4.0  2015/04/26
# 439     85.56    27.93  Sindhupalchowk  01:29        4.1  2015/04/26
# 440     85.43    27.71       Kathmandu  00:43        4.6  2015/04/26
# 441     85.55    27.94  Sindhupalchowk  00:14        4.1  2015/04/26
# 442     85.98    27.78  Sindhupalchowk  23:46        4.1  2015/04/25
#
# [443 rows x 6 columns]
